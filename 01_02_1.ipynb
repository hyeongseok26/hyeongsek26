# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeongseok26/hyeongsek26/blob/master/01_02_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,1,0.00001)
y = np.sin(60*x*2*np.pi)
plt.plot(x,y)
plt.grid()
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('60Hz sin ')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import animation, rc

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.0001)
y = np.sin(x)*np.random.rand(len(x))
line, = ax.plot(x, y)


def init():  # only required for blitting to give a clean slate.
    line.set_ydata([np.nan] * len(x))
    return line,


def animate(i):
    line.set_ydata(np.sin(x*300*np.pi) * (2*np.random.rand(len(x))-1))  # update the data.
    return line,


ani = animation.FuncAnimation(
    fig, animate, init_func=init, interval=2, blit=True, save_count=50)

rc('animation', html='html5')
ani
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
