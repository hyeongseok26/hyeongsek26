# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeongseok26/hyeongsek26/blob/master/scikit%26keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/2e/d0/860c4f6a7027e00acff373d9f5327f4ae3ed5872234b3cbdd7bcb52e5eff/scikit_learn-0.22-cp36-cp36m-manylinux1_x86_64.whl (7.0MB)
#      |████████████████████████████████| 7.0MB 2.8MB/s
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.3.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.17.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (0.14.1)
# Installing collected packages: scikit-learn
#   Found existing installation: scikit-learn 0.21.3
#     Uninstalling scikit-learn-0.21.3:
#       Successfully uninstalled scikit-learn-0.21.3
# Successfully installed scikit-learn-0.22

# %%
print(__doc__)


# Code source: Jaques Grobler
# License: BSD 3 clause


import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
# 0. 사용할 패키지 불러오기
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

x_train = np.squeeze(x_train)
x_val = np.squeeze(x_val)
x_test = np.squeeze(x_test)

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(32,input_dim=40,activation="relu"))
model.add(Dropout(0.3))
for i in range(2):
    model.add(Dense(32,activation="relu"))
    model.add(Dropout(0.3))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='adagrad')

# 4. 모델 학습시키기
hist = model.fit(x_train, y_train, epochs=200, batch_size=32, validation_data=(x_val, y_val))

# 5. 학습과정 살펴보기
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylim(0.0, 0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
          
# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, verbose=0)
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, verbose=0)
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, verbose=0)
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0, None]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(xhat, batch_size=32)
    predictions[i] = prediction
    xhat = np.hstack([xhat[:,1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 760 samples, validate on 360 samples
# Epoch 1/200
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 760/760 [==============================] - 1s 912us/step - loss: 0.1504 - val_loss: 0.0333
# Epoch 2/200
# 760/760 [==============================] - 0s 59us/step - loss: 0.0736 - val_loss: 0.0245
# Epoch 3/200
# 760/760 [==============================] - 0s 65us/step - loss: 0.0535 - val_loss: 0.0217
# Epoch 4/200
# 760/760 [==============================] - 0s 60us/step - loss: 0.0510 - val_loss: 0.0122
# Epoch 5/200
# 760/760 [==============================] - 0s 57us/step - loss: 0.0405 - val_loss: 0.0198
# Epoch 6/200
# 760/760 [==============================] - 0s 62us/step - loss: 0.0394 - val_loss: 0.0119
# Epoch 7/200
# 760/760 [==============================] - 0s 61us/step - loss: 0.0362 - val_loss: 0.0253
# Epoch 8/200
# 760/760 [==============================] - 0s 54us/step - loss: 0.0333 - val_loss: 0.0162
# Epoch 9/200
# 760/760 [==============================] - 0s 56us/step - loss: 0.0292 - val_loss: 0.0091
# Epoch 10/200
# 760/760 [==============================] - 0s 60us/step - loss: 0.0291 - val_loss: 0.0136
# Epoch 11/200
# 760/760 [==============================] - 0s 62us/step - loss: 0.0241 - val_loss: 0.0101
# Epoch 12/200
# 760/760 [==============================] - 0s 59us/step - loss: 0.0233 - val_loss: 0.0185
# Epoch 13/200
# 760/760 [==============================] - 0s 88us/step - loss: 0.0268 - val_loss: 0.0140
# Epoch 14/200
# 760/760 [==============================] - 0s 65us/step - loss: 0.0247 - val_loss: 0.0143
# Epoch 15/200
# 760/760 [==============================] - 0s 57us/step - loss: 0.0242 - val_loss: 0.0101
# Epoch 16/200
# 760/760 [==============================] - 0s 54us/step - loss: 0.
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0059 - val_loss: 0.0043
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0032 - val_loss: 0.0018
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0028 - val_loss: 0.0022
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0029 - val_loss: 0.0052
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0033 - val_loss: 0.0028
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0027 - val_loss: 0.0012
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0032 - val_loss: 0.0031
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0023 - val_loss: 0.0013
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0027 - val_loss: 3.3506e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 1.6396e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 5.1236e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0026 - val_loss: 6.3233e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 2.0297e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 4.6443e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0024 - val_loss: 1.9241e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 4.4607e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0024 - val_loss: 6.8418e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 15ms/step - loss: 0.0022 - val_loss: 5.1211e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.2895e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0024 - val_loss: 3.8832e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 7.5426e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0024 - val_loss: 8.6276e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.6982e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 3.3345e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 5.2714e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0023 - val_loss: 4.3449e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 3.4463e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 5.3820e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 4.8199e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 4.7218e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 5.8857e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 13s 17ms/step - loss: 0.0020 - val_loss: 7.3328e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 2.0141e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0023 - val_loss: 9.5959e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0027 - val_loss: 0.0010
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 3.8785e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 15ms/step - loss: 0.0017 - val_loss: 7.1534e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.5328e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0023 - val_loss: 9.6533e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 1.3600e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 6.1646e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0023 - val_loss: 5.8266e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 1.7145e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 2.0996e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.1619e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0023 - val_loss: 1.4619e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 3.3047e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.3465e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 8.4744e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 3.7796e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 4.1274e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.7311e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 8.0509e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 5.0657e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.6381e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.1044e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 15ms/step - loss: 0.0021 - val_loss: 2.8004e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 13s 16ms/step - loss: 0.0021 - val_loss: 5.0787e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 6.3783e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 7.4537e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 3.4299e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 2.1254e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.7223e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.1245e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.4108e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 3.8597e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.1730e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 2.5530e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 4.9549e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.2399e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.5642e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.0101e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 2.7201e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 2.0907e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0024 - val_loss: 3.0732e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 6.7387e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.0248e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.6217e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.1448e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 4.5964e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 7.9702e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.3488e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 4.3595e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 13s 17ms/step - loss: 0.0023 - val_loss: 1.9023e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 2.7097e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 4.0334e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.7405e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.7330e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.0825e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 5.0716e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.0676e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.9445e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 2.0394e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 2.0186e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0017 - val_loss: 8.7047e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 6.9043e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 3.8886e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.7185e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 6.6280e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.2463e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.1496e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 8.3702e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.2751e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.1261e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 4.3230e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 9.5400e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.6324e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 2.8034e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.5781e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0017 - val_loss: 1.0217e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 2.5988e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.0283e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.0262e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 4.6762e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.3642e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.1260e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 13s 17ms/step - loss: 0.0019 - val_loss: 2.2666e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 8.5779e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0017 - val_loss: 2.8913e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 2.2366e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0017 - val_loss: 2.2164e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.3997e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 2.5050e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.6561e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.8182e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 3.6339e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 2.9450e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.6720e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 6.6856e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.1659e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 2.6180e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.0022e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 4.9008e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 2.5162e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.5603e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 2.5200e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 1.5607e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 1.0434e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 3.9285e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 7.6360e-06
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.2856e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.0046e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 2.8342e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0017 - val_loss: 2.3784e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 4.9190e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 3.4958e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 2.3352e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 7.2917e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.7779e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0022 - val_loss: 3.4365e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 3.4187e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 2.7008e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.3949e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 2.3729e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 5.0984e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0021 - val_loss: 6.3749e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 8.0137e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 1.0936e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0019 - val_loss: 6.0458e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0017 - val_loss: 2.4262e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.1960e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 2.7315e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0020 - val_loss: 4.9739e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 1.8170e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 4.4204e-04
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 760/760 [==============================] - 12s 16ms/step - loss: 0.0018 - val_loss: 2.7469e-05
# Train on 760 samples, validate on 360 samples
# Epoch 1/1
# 745/760 [============================>.] - ETA: 0s - loss: 0.0019
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-b193028c093e> in <module>()
#      61
#      62 for i in range(200):
# ---> 63     model.fit(x_train, y_train, epochs=1, batch_size=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val, y_val))
#      64     model.reset_states()
#      65
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# 0. 사용할 패키지 불러오기
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

def create_dataset(signal_data, look_back=1):
    dataX, dataY = [], []
    for i in range(len(signal_data)-look_back):
        dataX.append(signal_data[i:(i+look_back), 0])
        dataY.append(signal_data[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

look_back = 40

# 1. 데이터셋 생성하기
signal_data = np.cos(np.arange(1600)*(20*np.pi/1000))[:,None]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
signal_data = scaler.fit_transform(signal_data)

# 데이터 분리
train = signal_data[0:800]
val = signal_data[800:1200]
test = signal_data[1200:]

# 데이터셋 생성
x_train, y_train = create_dataset(train, look_back)
x_val, y_val = create_dataset(val, look_back)
x_test, y_test = create_dataset(test, look_back)

# 데이터셋 전처리
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# 2. 모델 구성하기
model = Sequential()
for i in range(2):
    model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True, return_sequences=True))
    model.add(Dropout(0.3))
model.add(LSTM(32, batch_input_shape=(1, look_back, 1), stateful=True))
model.add(Dropout(0.3))
model.add(Dense(1))

# 3. 모델 학습과정 설정하기
model.compile(loss='mean_squared_error', optimizer='adam')

# 4. 모델 학습시키기
custom_hist = CustomHistory()
custom_hist.init()

for i in range(200):
    model.fit(x_train, y_train, epochs=1, batch_size=1, shuffle=False, callbacks=[custom_hist], validation_data=(x_val, y_val))
    model.reset_states()

# 5. 학습과정 살펴보기
plt.plot(custom_hist.train_loss)
plt.plot(custom_hist.val_loss)
plt.ylim(0.0, 0.15)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# 6. 모델 평가하기
trainScore = model.evaluate(x_train, y_train, batch_size=1, verbose=0)
model.reset_states()
print('Train Score: ', trainScore)
valScore = model.evaluate(x_val, y_val, batch_size=1, verbose=0)
model.reset_states()
print('Validataion Score: ', valScore)
testScore = model.evaluate(x_test, y_test, batch_size=1, verbose=0)
model.reset_states()
print('Test Score: ', testScore)

# 7. 모델 사용하기
look_ahead = 250
xhat = x_test[0]
predictions = np.zeros((look_ahead,1))
for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size=1)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:],prediction])
    
plt.figure(figsize=(12,5))
plt.plot(np.arange(look_ahead),predictions,'r',label="prediction")
plt.plot(np.arange(look_ahead),y_test[:look_ahead],label="test function")
plt.legend()
plt.show()
